# %%
pip install openpyxl
# Out:
# Collecting openpyxlNote: you may need to restart the kernel to use updated packages.
#
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      --- --------------------------------- 20.5/250.0 kB 217.9 kB/s eta 0:00:02
#      ---- --------------------------------- 30.7/250.0 kB 62.4 kB/s eta 0:00:04
#      --------- --------------------------- 61.4/250.0 kB 142.2 kB/s eta 0:00:02
#      ---------- -------------------------- 71.7/250.0 kB 151.3 kB/s eta 0:00:02
#      ---------- -------------------------- 71.7/250.0 kB 151.3 kB/s eta 0:00:02
#      ---------------- ------------------- 112.6/250.0 kB 198.4 kB/s eta 0:00:01
#      ----------------- ------------------ 122.9/250.0 kB 205.9 kB/s eta 0:00:01
#      ------------------------- ---------- 174.1/250.0 kB 262.1 kB/s eta 0:00:01
#      ---------------------------- ------- 194.6/250.0 kB 274.3 kB/s eta 0:00:01
#      -------------------------------- --- 225.3/250.0 kB 305.9 kB/s eta 0:00:01
#      ------------------------------------ 250.0/250.0 kB 313.0 kB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import pandas as pd

file_path = 'CTO NEW Study Tracking .xlsx'
sheet_name = 'CTONewTracking'

# Read the specified sheet from the Excel file
df = pd.read_excel(file_path, sheet_name=sheet_name)

# %%
df
# Out:
#        Orig. Submit Date IRB Submit Date Pause Date Restart Date  \
# 0    2023-12-01 00:00:00             NaT        NaT          NaN
# 1    2023-11-30 00:00:00             NaT        NaT          NaN
# 2    2023-11-29 00:00:00             NaT        NaT          NaN
# 3    2023-11-29 00:00:00             NaT        NaT          NaN
# 4    2023-11-28 00:00:00             NaT        NaT          NaN
# ..                   ...             ...        ...          ...
# 574  2021-09-10 00:00:00      2021-09-10 2022-11-21          NaN
# 575  2021-09-10 00:00:00      2021-09-10 2022-11-21          NaN
# 576  2021-02-17 00:00:00      2021-03-01 2022-11-21          NaN
# 577  2021-02-17 00:00:00      2021-03-01 2022-11-21          NaN
# 578  2019-07-19 00:00:00      2019-07-15 2023-08-22          NaN
#
#          Est. Start Date       eRS/WD     IRB           PI      SC       Dept  \
# 0                    NaN        64328  17644.0      Mwangi   M. Graf     Pulm
# 1                    NaN        64330  17730.0  Mikhalkova  M. Lesko   Cardio
# 2    2024-02-05 00:00:00        64322      NaN    Muzaffar  L. Weber    Radio
# 3                    NaN        64327      NaN    Muzaffar  L. Weber    Radio
# 4                    NaN        64323  17745.0  Philipneri   B. Egan  Nephrol
# ..                   ...          ...      ...         ...       ...      ...
# 574                  NaN  Award-01053  17649.0      Davitt       NaN  Ophthal
# 575                  NaN  Award-01053  17650.0      Davitt       NaN  Ophthal
# 576                  NaN  Award 01565  17630.0        Piri       NaN  Ophthal
# 577                  NaN  Award-01464  17629.0        Piri       NaN  Ophthal
# 578                  NaN  Award-01570  17539.0    Buchanan       NaN    ObGyn
#
#      ... CTO Checklist Rec'd IRB Ancillary Reviews Rec'd IRB Comments Sent  \
# 0    ...                 NaN                         NaN               NaN
# 1    ...                 NaN                         NaN               NaN
# 2    ...                 NaN                         NaN               NaN
# 3    ...                 NaN                         NaN               NaN
# 4    ...                 NaN                         NaN               NaN
# ..   ...                 ...                         ...               ...
# 574  ...                 NaN                         NaN               NaN
# 575  ...                 NaN                         NaN               NaN
# 576  ...                 NaN                         NaN               NaN
# 577  ...                 NaN                         NaN               NaN
# 578  ...                 NaN                         NaN               NaN
#
#     IRB SAF Signed Final IRB Approval Date Local IRB Review Complete TA  \
# 0              NaN                     NaT                          0.0
# 1              NaN                     NaT                          NaN
# 2              NaN                     NaT                          NaN
# 3              NaN                     NaT                          NaN
# 4              NaN                     NaT                          0.0
# ..             ...                     ...                          ...
# 574            NaN                     NaT                     -31750.0
# 575            NaN                     NaT                     -31750.0
# 576            NaN                     NaT                     -31611.0
# 577            NaN                     NaT                     -31611.0
# 578            NaN                     NaT                     -31186.0
#
#     CTO Checklist Rec'd TA IRB Ancillary Reviews Rec'd TA IRB Comment Sent TA  \
# 0                      0.0                            0.0                 0.0
# 1                      NaN                            NaN                 NaN
# 2                      NaN                            NaN                 NaN
# 3                      NaN                            NaN                 NaN
# 4                      0.0                            0.0                 0.0
# ..                     ...                            ...                 ...
# 574               -31750.0                       -31750.0            -31750.0
# 575               -31750.0                       -31750.0            -31750.0
# 576               -31611.0                       -31611.0            -31611.0
# 577               -31611.0                       -31611.0            -31611.0
# 578               -31186.0                       -31186.0            -31186.0
#
#      SIRB Approval TA
# 0                 0.0
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 0.0
# ..                ...
# 574               0.0
# 575               0.0
# 576               0.0
# 577               0.0
# 578               0.0
#
# [579 rows x 64 columns]

# %%
from sqlalchemy import create_engine

engine = create_engine('mssql+pyodbc:///?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server&server=.&database=Data_5710')

df.to_sql("CTO", engine, if_exists='replace', index=False)
# Out:
# 3
